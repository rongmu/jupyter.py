# %%
# %matplotlib inline

import feather
import matplotlib.pyplot as plt
import seaborn as sns


mtcars = feather.read_dataframe('mtcars.feather')

# %%
sns.set_style('white')

# make plots great again!!
with plt.xkcd():
    sns.jointplot(x='mpg', y='wt', data=mtcars, kind='reg', xlim=(5, 40), ylim=(0, 6))
