# %%
# %matplotlib inline

import feather
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white')
plt.xkcd()  ## use XKCD comics style !!

# %%
mtcars = feather.read_dataframe('mtcars.feather')

sns.jointplot(x='mpg', y='wt', data=mtcars, kind='reg')
